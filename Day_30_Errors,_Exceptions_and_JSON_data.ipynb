# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_30_Errors%2C_Exceptions_and_JSON_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# TYPES OF ERRORS POSSIBLE IN PYTHON:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# CATCHING ERROR:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# TRY: Tries the block of code to see if there is any error
#
# EXCEPTION: if there is a error in TRY block, then code in this block runs
#
# ELSE: if there is no error in TRY block, then this code runs. If there is a error, the code in this block doesn't run and only the code in EXCEPTION blocks runs
#
# FINALLY: this code is always executed

# %% [markdown]
# It's always recommended to mention the error after EXCEPT clause, just so that the code knows what specific error to exclude. Else it would exclude all the errors
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# FINAL CODE WITH ALL BLOCKS:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **RAISING YOUR OWN EXCEPTIONS:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **JSON DATA**
# JavaScriptObjectNotation
#
# -Common method of transfering data across internet. Almost similar to python dictionary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Python operation for JSON:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can use dump to write all things into a file:
#
# ![image.png](data:image/png;base64,...)
#
# Use indent to format the output:
#
# ![image.png](data:image/png;base64,...)
#
# Without indent:
#
# ![image.png](data:image/png;base64,...)
#
# With indent:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# LOAD method to open and read a JSON file
#
# ![image.png](data:image/png;base64,...)
#
# It would open as a python DICTIONARY
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# UPDATE method to add a new item to the JSON file
#
# What we do below code is that we open the JSON file in python as a new variable, add our item to the new variable, and then write back the variable back into JSON file
#
# ![image.png](data:image/png;base64,...)
#
# Ebay data added newly
#
# ![image.png](data:image/png;base64,...)
