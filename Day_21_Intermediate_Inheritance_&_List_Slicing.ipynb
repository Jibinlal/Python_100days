# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_21_Intermediate_Inheritance_%26_List_Slicing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CLASS INHERITANCE**
# When you want a same copy of a class and add more methods, then we use the concept of class inheritance
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can do class inheritance, by adding the class name in the brackets. For instance, in below example we mention that the Fish class inherits from Animal class. Also, we need to add a line 'super().__init__()', where super refers to the super class i.e., Animal
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# For example,
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can also modify the method which was in the super class and add new code to that (see the method breathe)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# By using inheritance, we can modify the class developed by someone else and add new method or variables.

# %% [markdown]
# # **SLICING:**
#
# If you want to slice a list or tuple, then use the following code. Note the positions, if you want c,d,e then use position 2:5
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Slicing has various functionalities as below:
#
# 1.  From a position, to end of list
# ![image.png](data:image/png;base64,...)
#
# 2. All items upto a position
# ![image.png](data:image/png;base64,...)
#
# 3. Specifiy a 3rd number to specify a increment to have every other item
# ![image.png](data:image/png;base64,...)
# 4. You can just specifiy increment as well
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 5. You can use a -1 to reverse the list
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Same things as above can be used for Tuple as well
#
# ![image.png](data:image/png;base64,...)
