# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_35_Keys%2C_Authentication_Environment_Variables_Send_SMS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Some API are free, but some are paid as well. For instance, an API which provides weather data are paid. They have some free tiers as well,which can be used for testing.
#
# These APIs use a API key for authentication
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This authetication key can be used after signing up for the service and this key can be stored in the code
#
# SAMPLE OUTPUT:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can use Twilio api to send SMS and we will do it using the trial feature
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When you type **env** into console it would give you a list of enivronmental vairbales. Now this would be different for desktop App and pythonAnywhere site. Following is a screenshot from App (ios and windows) and pythonAnywhere
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This is for convenience and security. For instance, you can store the authentication keys in your enivroment using the following code and then change the code to take it from environment using OS library
#
# ![image.png](data:image/png;base64,...)
#
# Key added to env:
#
# ![image.png](data:image/png;base64,...)
#
# You can change the vairable now
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can also add this env variable to the task scheduler (another way of doing the same thing as above)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# This is mainly used when you upload your code publically - like github or Bitbucket. This can prevent other people from getting your password or authentication keys

# %% [markdown]
# Other APIs to explore: https://apilist.fun/
