# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/DAY_37_Habit_tracking_project_API_Post_requests_%26_Headers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **HTTP Requests:**
#
# ![image.png](data:image/png;base64,...)
#
# get() -- gets data from external site
# post() -- send data to external site. we do receive back data but we are not interested in it. we can use the received data to see if it was successfull
# put() -- to update data in external site
# delete() -- to delete data in external site
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# EXAMPLE OF POST:
#
# ![image.png](data:image/png;base64,...)
