# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/DAY_25_Intermediate_Working_with_CSV_data_and_the_Pandas_Library.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CSV Files and Pandas Library:**

# %% [markdown]
# CSV files are comma seperated items.
#
# ![image.png](data:image/png;base64,...)
#
# If you would open using the same logic as normal text files (readlines which reads each and every single line), then this doesn't give a correct input for us
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can use a csv libraray to extract a particular column, but again this is lot of code to write
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Thats when Pandas library comes in handy. It can get any column in just 2 lines of code and output is formatted as well
#
# https://pandas.pydata.org/docs/
# https://pandas.pydata.org/docs/reference/index.html
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **PANDAS - OPERATIONS:**

# %% [markdown]
# Pandas has 2 structures. Series - each column is stored as a series (put simply, a list) and the entire table is stored as DataFrame.
# ![image.png](data:image/png;base64,...)
#
#
# We have separate operations for both of these and you can use them depending on your need (Found in api documentation page - link above)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Converting entire data into dictionary: (dataframe)
#
# ![image.png](data:image/png;base64,...)
#
# Convert column to a list: (Series)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can get data from columns in 2 ways and both works the same way. The second method works because Pandas gets each column and stores it as a attribute
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Please note that the column names are CASE-SENSITIVE!! We have to use the exact column names

# %% [markdown]
# Getting data from rows:
# Go into data and go into the column value for which you need row value for
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# We can also get the row by a different way. Do note that, inside data if you use the column name, then you would just get the column values. If you filter by a condition, then you get the entire row value
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can also search by tapping into a particular row and then getting a particular value
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Create a dataframe from scratch
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Or you can directly convert it into a csv file instead
#
# ![image.png](data:image/png;base64,...)
