# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_19_Instances%2C_State%2C_Higher_Order_fucntions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Event listners: listen to what the user does. For instance, typing on a keyboard
#
# In following example, We use Listen() method to let the code to know that we will have to take a user input. Then we call the function - move_forwards when the space key is pressed.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Higher Order functions**
#
#
# Imp note that in above example, where we call a function (move_forwards) inside another function (onkey), we don't need to use open and close brackets. And this kind of way in which we call a function inside another function is called Higher Order functions
#
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Instances and State:**
#
# you can create multiple objects from the same class.
#
# ![image.png](data:image/png;base64,...)
#
# Each of the object created are independent and in programming, we call them separate INSTANCES.
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Also, in programming these objects can be performing different things, called as its state. For instance, in following example the objects are in different state
#
# ![image.png](data:image/png;base64,...)
