# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_32_Send_Email(smtplib)_and_Manage_dates(datetime).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
SMTP:

# %% [markdown]
# # **SMTP**
#
# SMTP - rules for sending and receiving email
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# To put it simply, SMTP is the post man who knows how to send and receive posts and deliver it to the recipient
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Documentation for SMTP lib:
#
# https://docs.python.org/3/library/smtplib.html

# %% [markdown]
# Code: sections:
# starttls is to encrypt our connection
#
# ![image.png](data:image/png;base64,...)
#
#
# Each provider has different SMTP's
#
# Gmail: smtp.gmail.com
#
# Hotmail: smtp.live.com
#
# Outlook: outlook.office365.com
#
# Yahoo: smtp.mail.yahoo.com
#
# If you use another email provider, just Google for your email provider e.g. "Gmail SMTP address"

# %% [markdown]
# To send email from gmail, you have to do change 2 settings:
#
# ![image.png](data:image/png;base64,...)
#
# Turn ON less secure apps
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# FINAL CODE:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Authetication and security setting may differe for each account. Say, if your account is yahoo, then you would need to get custom app password and use that in your code
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **DATETIME MODULE:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)
