# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_26_Intermediate_List_comprehension_and_NATO_Alphabet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **LIST COMPREHENSION:**
#
# One of the most powerful feature of Python, where in you can modify or change an exisiting code without writing a lot of code

# %% [markdown]
# Generally to add an item to a list you would use for loop. Now you can use a simple List comprehension method
#
# ![image.png](data:image/png;base64,...)
#
# Comparing both methods:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can also use it for words. Each letter would be separated.
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Doing the same for a range:
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can do list comprehension for all the items below (commonly called Python Sequences - ordered)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **CONDITIONAL LIST COMPREHENSION:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Examples of conditional list comprehension:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **DICTIONARY COMPREHENSION:**

# %% [markdown]
# 3 WAYS:
#
# Create a dictionary from a list:
#
# ![image.png](data:image/png;base64,...)
#
# Create a dictionary from a dictionary:
#
# ![image.png](data:image/png;base64,...)
#
# Using a condition:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Examples of above:
#
# Dictionary from a list:
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Dicitionary from a dictionary with a condition:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **ITERATE OVER PANDAS DATAFRAME:**
#
# ![image.png](data:image/png;base64,...)
#
# You can get each row by this method:
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Also you can get value in each row by using the following:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Index refers to the index in the dataframe:
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
