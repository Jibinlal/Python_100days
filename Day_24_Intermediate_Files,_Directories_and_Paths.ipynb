# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_24_Intermediate_Files%2C_Directories_and_Paths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Reading and writing into a file:**
#
# Normally, you would upload the file to the project directory and use open() command. But in this way you will always have to use close() to close the file open in Python.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Another way is to use 'With' wherein you don't have to do close the file (Which is commonly used by programmers)
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Default mode of open. So if you want to change the things written inside, then change it to write mode and then add text. If there is no file to write, then it would create a new text file and then add the text. Note that this would replace all the exisiting text
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can add new line by using Append mode
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # **FILE PATHS:**

# %% [markdown]
# **ABSOLUTE FILE PATH:**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **RELATIVE FILE PATH:**
#  Relative path is used when you are working in the same folder and want to access another item in the same folder. For instance, say you are working with Main.py in Project folder as below. If you want to access talk.ppt from same folder, then use ./talk.ppt or just talk.ppt
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Similar to above scenario, say if you working in the Work folder but want to access the talk.ppt, then the relative file path would be
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Also, if you want to go upwards using relative file path, then use 2 dots to go to the folder before (parent folder)
#
# ![image.png](data:image/png;base64,...)
#
# If you want to go 2 folders above, then it would be ../../report.doc
#
# ![image.png](data:image/png;base64,...)
