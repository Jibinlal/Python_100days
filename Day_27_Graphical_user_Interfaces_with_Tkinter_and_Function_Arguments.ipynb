# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_27_Graphical_user_Interfaces_with_Tkinter_and_Function_Arguments.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Default value arguments:
#
# ![image.png](data:image/png;base64,...)
#
#
# If you just want to change a particular value in the default value function, say just b, then you can do by the following
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Many positional arguments: *args
#
# You can add as many arugments as you want when you use *args
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Imp note: *args is an ordered arguments, hence called positional. The values passed are stored in form of Tuple
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# KEYOWORD ARGUMENTS: **kwargs
# Note kwargs are stored as dictionary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can access the values in kwargs in 2 ways: Looping or accessing it as dictionary
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You can also initialize a class and have arguments (go through lecture to understand better)
#
#
# ![image.png](data:image/png;base64,...)
