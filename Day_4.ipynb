# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Randomization and Python lists**

# %%
# Random
# https://www.askpython.com/python-modules/python-random-module-generate-random-numbers-sequences
import random
val = random.randint(1,10)
print(val)
# Out:
# 5

# %%
# Random float
val = random.random()
print(val)
# Random decimal number between 0 and 5?
val = random.random()*4
print(val)
# Out:
# 0.6390928436088527
# 0.3514977156086916

# %%
# Heads or Tails
import random
val = random.randint(0,1)
if(val == 0):
    print ("Heads")
elif(val == 1):
    print("Tails")
# Out:
# Tails

# %% [markdown]
# **Python List**
#
# *   Why? - because you can store multiple valus instead of using multiple variables (eg. All states in US)
# *   And when you need to have a *order* (eg. store virtual queue of people data)
# *   List can *store multiple datatype*
#
# **Syntax**
#
#   Fruits = [item1, item2]
#
# Note: You would use *square brackets* to create a list and also to call an item in the list

# %%
states_of_america = ["Delaware","Pennsylvania","New Jersey","Georgia"]
print(states_of_america[0])
print(states_of_america[3])
# Out:
# Delaware
# Georgia

# %%
# You could also use a negative index
print(states_of_america[-1]) #there is no zero negative in
print(states_of_america[-3])
# Out:
# Georgia
# Pennsylvania

# %%
# You can also edit item in a list
states_of_america[1] = "Pencilvania"
print(states_of_america)
# Out:
# ['Delaware', 'Pencilvania', 'New Jersey', 'Georgia']

# %%
# Append an item to end of the list
states_of_america.append("Angelaland")
print(states_of_america)
# Out:
# ['Delaware', 'Pencilvania', 'New Jersey', 'Georgia', 'Angelaland']

# %%
#Use extend method to add another list to an exisiting list
states_of_america.extend(["Jack Land","Unknown land"])
print(states_of_america)
# Out:
# ['Delaware', 'Pencilvania', 'New Jersey', 'Georgia', 'Angelaland', 'Jack Land', 'Unknown land']

# %% [markdown]
# There are many other methods which we can perform on list: (Don't mugup! Just have a look at all the posibilities)
#
# https://docs.python.org/3/tutorial/datastructures.html

# %%
# CODING EXERCISE
# You are going to write a program that will select a random name from a list of names. 
  # The person selected will have to pay for everybody's food bill.

import random
test_seed = int(input("Create a seed number: "))
random.seed(test_seed)

names_string = input("Give me everybody's names, separated by a comma. ")
names = names_string.split(", ")

lent = len(names)
no = random.randint(0,lent-1)

print(f"{names[no]} is going to buy the meal today!")
# Out:
# Create a seed number: 687
# Give me everybody's names, separated by a comma. Angela, Ben, Jenny, Michael, Chloe
# Michael is going to buy the meal today!

# %%
# NESTED LISTS
fruits = ["apple","papaya","banana"]
vegetable = ["carrot","beans","betroot","potato"]

combined = [fruits,vegetable]
print(combined)

print(combined[1][1])
# Out:
# [['apple', 'papaya', 'banana'], ['carrot', 'beans', 'betroot', 'potato']]
# beans

# %% [markdown]
# **Coding Exercise**
# You are going to write a program that will mark a spot with an X.
# Your job is to write a program that allows you to mark a square on the map using a two-digit system. The first digit is the vertical column number and the second digit is the horizontal row number. e.g.:
#
# ![image.png](data:image/png;base64,...)

# %%
# 🚨 Don't change the code below 👇
row1 = ["⬜️","⬜️","⬜️"]
row2 = ["⬜️","⬜️","⬜️"]
row3 = ["⬜️","⬜️","⬜️"]
map = [row1, row2, row3]
print(f"{row1}\n{row2}\n{row3}")
position = input("Where do you want to put the treasure? ")
# 🚨 Don't change the code above 👆

#Write your code below this row 👇
row = int(position[0])-1
column = int(position[1])-1
map [row][column] = "'X'"

#Write your code above this row 👆

# 🚨 Don't change the code below 👇
print(f"{row1}\n{row2}\n{row3}")
# Out:
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', '⬜️', '⬜️']
# Where do you want to put the treasure? 22
# ['⬜️', '⬜️', '⬜️']
# ['⬜️', "'X'", '⬜️']
# ['⬜️', '⬜️', '⬜️']

# %%
rock = '''
    _______
---'   ____)
      (_____)
      (_____)
      (____)
---.__(___)
'''

paper = '''
    _______
---'   ____)____
          ______)
          _______)
         _______)
---.__________)
'''

scissors = '''
    _______
---'   ____)____
          ______)
       __________)
      (____)
---.__(___)
'''

#Write your code below this line 👇
import random

choice = int(input("What do you choose? Type 0 for Rock, 1 for Paper or 2 for Scissors.") )
opt = [rock,paper,scissors]
userchoice = opt[choice]
print(userchoice)

compopt = random.randint(0,2)
compchoice = opt[compopt]
print("computer chose: " + compchoice)

Rock
# Out:
# What do you choose? Type 0 for Rock, 1 for Paper or 2 for Scissors.1
#
#     _______
# ---'   ____)____
#           ______)
#           _______)
#          _______)
# ---.__________)
#
# computer chose:
#     _______
# ---'   ____)
#       (_____)
#       (_____)
#       (____)
# ---.__(___)
