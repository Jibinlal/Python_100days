# %% [markdown]
# <a href="https://colab.research.google.com/github/Jibinlal/Python_100days/blob/master/Day_18_Intermediate_Turtle_and_GUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing module - 2 ways**
#
# ![image.png](data:image/png;base64,...)
#
# If you would need to call the module frequently, then use the below method
#
# ![image.png](data:image/png;base64,...)
#
# Another way is to import everything: (Not recommended though)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Importing with alias name:
#
# ![image.png](data:image/png;base64,...)
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Tuples:**
#
# Tuples are similar to List. They are represented by round brackets and each items are ordered. Only difference is that they are immutable, that is you can never change the values once a tuple is created
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You cannot change the value of tuple
# ![image.png](data:image/png;base64,...)
